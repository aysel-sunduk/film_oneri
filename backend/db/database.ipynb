# %%
import pandas as pd
from sqlalchemy import create_engine

df = pd.read_csv("D:\\Film_oneri\\imdb_top_1000.csv")

df.columns = [c.lower() for c in df.columns]  # tüm kolon isimlerini küçük harfe çevir

engine = create_engine("postgresql://postgres:asel.02@localhost:5433/film")

df.to_sql("movies", engine, if_exists="append", index=False)
# Out:
# 1000
